# %%
import pandas as pd
import numpy as np

# %%
boolean=[True,False]
gender=["男","女"]
color=["white","black","yellow"]
data=pd.DataFrame({
    "height":np.random.randint(150,190,100),
    "weight":np.random.randint(40,90,100),
    "smoker":[boolean[x] for x in np.random.randint(0,2,100)],
    "gender":[gender[x] for x in np.random.randint(0,2,100)],
    "age":np.random.randint(15,90,100),
    "color":[color[x] for x in np.random.randint(0,len(color),100) ]
}
)

# %%
data
# Out:
#     height  weight  smoker gender  age   color
# 0      168      66   False      女   89   white
# 1      156      75   False      男   44   black
# 2      179      75   False      女   37  yellow
# 3      181      41   False      男   82   white
# 4      165      60   False      女   46  yellow
# ..     ...     ...     ...    ...  ...     ...
# 95     161      67   False      男   56  yellow
# 96     153      57   False      男   45  yellow
# 97     181      84   False      男   74   white
# 98     153      49   False      男   59   white
# 99     160      59   False      女   88  yellow
#
# [100 rows x 6 columns]

# %%
data["gender"] = data["gender"].map({"男":1, "女":0})
